# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import csv
import os
import logging

logging.basicConfig(level=logging.INFO)

NUM_OF_YEARS = 10

# Функција за проверка дали стрингот содржи бројка
def has_num(shifra):
    return any(char.isdigit() for char in shifra)

# Функција за преземање на тикерите
def fetch_tikeri_bs():
    url = 'https://www.mse.mk/mk/stats/symbolhistory/kmb'
    response = requests.get(url)
    
    if response.status_code != 200:
        logging.error("Не успеав да ја превземам страната.")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    dropdown = soup.find('select', {'id': 'Code'})
    options = dropdown.find_all('option') if dropdown else []
    
    # Преземи тикери без броеви
    tikeri = [option['value'] for option in options if not has_num(option['value'])]
    return tikeri

# Функција за преземање на историски податоци за секој тикер
def fetch_historic_data_bs4(ticker):
    base_url = f"https://www.mse.mk/mk/stats/symbolhistory/{ticker.lower()}"
    historic_data = []
    date_to = datetime.now()
    
    for _ in range(NUM_OF_YEARS):
        date_from = date_to - timedelta(days=365)
        params = {
            "FromDate": date_from.strftime("%d.%m.%Y"),
            "ToDate": date_to.strftime("%d.%m.%Y"),
        }
        
        try:
            response = requests.get(base_url, params=params)
            if response.status_code != 200:
                logging.warning(f"Неуспешно преземање на податоци за {ticker}.")
                continue

            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.select_one('#resultsTable > tbody')

            if table:
                rows = table.find_all('tr')
                for row in rows:
                    data_row = [cell.text.strip() for cell in row.find_all('td')]
                    if data_row:
                        # Додај го тикерот како прва колона
                        data_row.insert(0, ticker)
                        historic_data.append(data_row)
            
            date_to = date_from

        except Exception as e:
            logging.error(f"Грешка при преземање на податоци за {ticker}: {e}")
    
    return historic_data

# Функција за зачувување на податоци во заеднички CSV фајл
def save_to_csv(data):
    filename = "mse_data.csv"
    file_exists = os.path.isfile(filename)
    
    # Отвори CSV фајл во режим на додавање (append)
    with open(filename, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        
        # Додај ја заглавната линија ако фајлот е нов
        if not file_exists:
            writer.writerow(["Tiker", "Datum", "Otvorena cena", "Najgolema cena", "Najmala cena", "Zatvorena cena", "Volumen", "Promet"])
        
        # Запиши ги податоците
        for row in data:
            writer.writerow(row)

# Главна функција за преземање и зачувување на податоци за сите тикери
def main():
    tickers = fetch_tikeri_bs()
    logging.info(f"Пронајдени тикери: {tickers}")

    all_data = []
    
    for ticker in tickers:
        logging.info(f"Преземам податоци за {ticker}...")
        data = fetch_historic_data_bs4(ticker)
        
        if data:
            all_data.extend(data)
        else:
            logging.warning(f"Нема достапни податоци за {ticker}.")
    
    if all_data:
        save_to_csv(all_data)
        logging.info("Сите податоци се зачувани во mse_data.csv.")
    else:
        logging.warning("Нема нови податоци за зачувување.")

# Повикај ја главната функција
if __name__ == "__main__":
    main()
# Out:
# INFO:root:Пронајдени тикери: ['ADIN', 'ALK', 'ALKB', 'AMEH', 'APTK', 'ATPP', 'AUMK', 'BANA', 'BGOR', 'BIKF', 'BIM', 'BLTU', 'CBNG', 'CDHV', 'CEVI', 'CKB', 'CKBKO', 'DEBA', 'DIMI', 'EDST', 'ELMA', 'ELNC', 'ENER', 'ENSA', 'EUHA', 'EUMK', 'EVRO', 'FAKM', 'FERS', 'FKTL', 'FROT', 'FUBT', 'GALE', 'GDKM', 'GECK', 'GECT', 'GIMS', 'GRDN', 'GRNT', 'GRSN', 'GRZD', 'GTC', 'GTRG', 'IJUG', 'INB', 'INHO', 'INOV', 'INPR', 'INTP', 'JAKO', 'JUSK', 'KARO', 'KDFO', 'KJUBI', 'KKST', 'KLST', 'KMB', 'KMPR', 'KOMU', 'KONF', 'KONZ', 'KORZ', 'KPSS', 'KULT', 'KVAS', 'LAJO', 'LHND', 'LOTO', 'LOZP', 'MAGP', 'MAKP', 'MAKS', 'MB', 'MERM', 'MKSD', 'MLKR', 'MODA', 'MPOL', 'MPT', 'MPTE', 'MTUR', 'MZHE', 'MZPU', 'NEME', 'NOSK', 'OBPP', 'OILK', 'OKTA', 'OMOS', 'OPFO', 'OPTK', 'ORAN', 'OSPO', 'OTEK', 'PELK', 'PGGV', 'PKB', 'POPK', 'PPIV', 'PROD', 'PROT', 'PTRS', 'RADE', 'REPL', 'RIMI', 'RINS', 'RZEK', 'RZIT', 'RZIZ', 'RZLE', 'RZLV', 'RZTK', 'RZUG', 'RZUS', 'SBT', 'SDOM', 'SIL', 'SKON', 'SKP', 'SLAV', 'SNBT', 'SNBTO', 'SOLN', 'SPAZ', 'SPAZP', 'SPOL', 'SSPR', 'STB', 'STBP', 'STIL', 'STOK', 'TAJM', 'TBKO', 'TEAL', 'TEHN', 'TEL', 'TETE', 'TIKV', 'TKPR', 'TKVS', 'TNB', 'TRDB', 'TRPS', 'TRUB', 'TSMP', 'TSZS', 'TTK', 'TTKO', 'UNI', 'USJE', 'VARG', 'VFPM', 'VITA', 'VROS', 'VSC', 'VTKS', 'ZAS', 'ZILU', 'ZILUP', 'ZIMS', 'ZKAR', 'ZPKO', 'ZPOG', 'ZUAS']
# INFO:root:Преземам податоци за ADIN...
# INFO:root:Преземам податоци за ALK...
# INFO:root:Преземам податоци за ALKB...
# INFO:root:Преземам податоци за AMEH...
# INFO:root:Преземам податоци за APTK...
# INFO:root:Преземам податоци за ATPP...
# INFO:root:Преземам податоци за AUMK...
# INFO:root:Преземам податоци за BANA...
# INFO:root:Преземам податоци за BGOR...
# INFO:root:Преземам податоци за BIKF...
# INFO:root:Преземам податоци за BIM...
# INFO:root:Преземам податоци за BLTU...
# INFO:root:Преземам податоци за CBNG...
# INFO:root:Преземам податоци за CDHV...
# INFO:root:Преземам податоци за CEVI...
# INFO:root:Преземам податоци за CKB...
# INFO:root:Преземам податоци за CKBKO...
# INFO:root:Преземам податоци за DEBA...
# INFO:root:Преземам податоци за DIMI...
# INFO:root:Преземам податоци за EDST...
# INFO:root:Преземам податоци за ELMA...
# INFO:root:Преземам податоци за ELNC...
# INFO:root:Преземам податоци за ENER...
# INFO:root:Преземам податоци за ENSA...
# INFO:root:Преземам податоци за EUHA...
# INFO:root:Преземам податоци за EUMK...
# INFO:root:Преземам податоци за EVRO...
# INFO:root:Преземам податоци за FAKM...
# INFO:root:Преземам податоци за FERS...
# INFO:root:Преземам податоци за FKTL...
# INFO:root:Преземам податоци за FROT...
# INFO:root:Преземам податоци за FUBT...
# INFO:root:Преземам податоци за GALE...
# INFO:root:Преземам податоци за GDKM...
# INFO:root:Преземам податоци за GECK...
# INFO:root:Преземам податоци за GECT...
# INFO:root:Преземам податоци за GIMS...
# INFO:root:Преземам податоци за GRDN...
# INFO:root:Преземам податоци за GRNT...
# INFO:root:Преземам податоци за GRSN...
# INFO:root:Преземам податоци за GRZD...
# INFO:root:Преземам податоци за GTC...
# INFO:root:Преземам податоци за GTRG...
# INFO:root:Преземам податоци за IJUG...
# INFO:root:Преземам податоци за INB...
# INFO:root:Преземам податоци за INHO...
# INFO:root:Преземам податоци за INOV...
# INFO:root:Преземам податоци за INPR...
# INFO:root:Преземам податоци за INTP...
# INFO:root:Преземам податоци за JAKO...
# INFO:root:Преземам податоци за JUSK...
# INFO:root:Преземам податоци за KARO...
# INFO:root:Преземам податоци за KDFO...
# INFO:root:Преземам податоци за KJUBI...
# INFO:root:Преземам податоци за KKST...
# INFO:root:Преземам податоци за KLST...
# INFO:root:Преземам податоци за KMB...
# INFO:root:Преземам податоци за KMPR...
# INFO:root:Преземам податоци за KOMU...
# INFO:root:Преземам податоци за KONF...
# INFO:root:Преземам податоци за KONZ...
# INFO:root:Преземам податоци за KORZ...
# INFO:root:Преземам податоци за KPSS...
# INFO:root:Преземам податоци за KULT...
# INFO:root:Преземам податоци за KVAS...
# INFO:root:Преземам податоци за LAJO...
# INFO:root:Преземам податоци за LHND...
# INFO:root:Преземам податоци за LOTO...
# INFO:root:Преземам податоци за LOZP...
# INFO:root:Преземам податоци за MAGP...
# INFO:root:Преземам податоци за MAKP...
# INFO:root:Преземам податоци за MAKS...
# INFO:root:Преземам податоци за MB...
# INFO:root:Преземам податоци за MERM...
# INFO:root:Преземам податоци за MKSD...
# INFO:root:Преземам податоци за MLKR...
# INFO:root:Преземам податоци за MODA...
# INFO:root:Преземам податоци за MPOL...
# INFO:root:Преземам податоци за MPT...
# INFO:root:Преземам податоци за MPTE...
# INFO:root:Преземам податоци за MTUR...
# INFO:root:Преземам податоци за MZHE...
# INFO:root:Преземам податоци за MZPU...
# INFO:root:Преземам податоци за NEME...
# INFO:root:Преземам податоци за NOSK...
# INFO:root:Преземам податоци за OBPP...
# INFO:root:Преземам податоци за OILK...
# INFO:root:Преземам податоци за OKTA...
# INFO:root:Преземам податоци за OMOS...
# INFO:root:Преземам податоци за OPFO...
# INFO:root:Преземам податоци за OPTK...
# INFO:root:Преземам податоци за ORAN...
# INFO:root:Преземам податоци за OSPO...
# INFO:root:Преземам податоци за OTEK...
# INFO:root:Преземам податоци за PELK...
# INFO:root:Преземам податоци за PGGV...
# INFO:root:Преземам податоци за PKB...
# INFO:root:Преземам податоци за POPK...
# INFO:root:Преземам податоци за PPIV...
# INFO:root:Преземам податоци за PROD...
# INFO:root:Преземам податоци за PROT...
# INFO:root:Преземам податоци за PTRS...
# INFO:root:Преземам податоци за RADE...
# INFO:root:Преземам податоци за REPL...
# INFO:root:Преземам податоци за RIMI...
# INFO:root:Преземам податоци за RINS...
# INFO:root:Преземам податоци за RZEK...
# INFO:root:Преземам податоци за RZIT...
# INFO:root:Преземам податоци за RZIZ...
# INFO:root:Преземам податоци за RZLE...
# INFO:root:Преземам податоци за RZLV...
# INFO:root:Преземам податоци за RZTK...
# INFO:root:Преземам податоци за RZUG...
# INFO:root:Преземам податоци за RZUS...
# INFO:root:Преземам податоци за SBT...
# INFO:root:Преземам податоци за SDOM...
# INFO:root:Преземам податоци за SIL...
# INFO:root:Преземам податоци за SKON...
# INFO:root:Преземам податоци за SKP...
# INFO:root:Преземам податоци за SLAV...
# INFO:root:Преземам податоци за SNBT...
# INFO:root:Преземам податоци за SNBTO...
# INFO:root:Преземам податоци за SOLN...
# INFO:root:Преземам податоци за SPAZ...
# INFO:root:Преземам податоци за SPAZP...
# INFO:root:Преземам податоци за SPOL...
# INFO:root:Преземам податоци за SSPR...
# INFO:root:Преземам податоци за STB...
# INFO:root:Преземам податоци за STBP...
# INFO:root:Преземам податоци за STIL...
# INFO:root:Преземам податоци за STOK...
# INFO:root:Преземам податоци за TAJM...
# INFO:root:Преземам податоци за TBKO...
# INFO:root:Преземам податоци за TEAL...
# INFO:root:Преземам податоци за TEHN...
# INFO:root:Преземам податоци за TEL...
# INFO:root:Преземам податоци за TETE...
# INFO:root:Преземам податоци за TIKV...
# INFO:root:Преземам податоци за TKPR...
# INFO:root:Преземам податоци за TKVS...
# INFO:root:Преземам податоци за TNB...
# INFO:root:Преземам податоци за TRDB...
# INFO:root:Преземам податоци за TRPS...
# INFO:root:Преземам податоци за TRUB...
# INFO:root:Преземам податоци за TSMP...
# INFO:root:Преземам податоци за TSZS...
# INFO:root:Преземам податоци за TTK...
# INFO:root:Преземам податоци за TTKO...
# INFO:root:Преземам податоци за UNI...
# INFO:root:Преземам податоци за USJE...
# INFO:root:Преземам податоци за VARG...
# INFO:root:Преземам податоци за VFPM...
# INFO:root:Преземам податоци за VITA...
# INFO:root:Преземам податоци за VROS...
# INFO:root:Преземам податоци за VSC...
# INFO:root:Преземам податоци за VTKS...
# INFO:root:Преземам податоци за ZAS...
# INFO:root:Преземам податоци за ZILU...
# INFO:root:Преземам податоци за ZILUP...
# INFO:root:Преземам податоци за ZIMS...
# INFO:root:Преземам податоци за ZKAR...
# INFO:root:Преземам податоци за ZPKO...
# INFO:root:Преземам податоци за ZPOG...
# INFO:root:Преземам податоци за ZUAS...
# INFO:root:Сите податоци се зачувани во mse_data.csv.
